# %%
import os
import sys

# %%
import pandas as pd

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0, module_path)

# %%
from spectroscopy.utils import DATA_DIR, parse_abs_files

# %% [markdown]
# # load in ABS files

# %%
dfs = [pd.read_csv(filename) for filename in DATA_DIR.glob('*.ABS')]

# %%
len(dfs)
# Out:
# 96

# %% [markdown]
# # explore one file

# %%
df = dfs[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                               --------------  -----
#  0    File: Users\stell\Desktop\StellarDat\South 18
#   ABSOR->  Wave:1277.42nm  Pix:248  Val:  0.180  Time: 40ms  Avg:10  Sm:2  Sg:0  Tc:off  SNAP  Xt:3  Ch:1  Xtrig    510 non-null    object
# dtypes: object(1)
# memory usage: 4.1+ KB

# %%
df.head()
# Out:
#    File: Users\stell\Desktop\StellarDat\South 18 \r\n  ABSOR->  Wave:1277.42nm  Pix:248  Val:  0.180  Time: 40ms  Avg:10  Sm:2  Sg:0  Tc:off  SNAP  Xt:3  Ch:1  Xtrig
# 0                                862.13  1.0000E-003
# 1                                863.88  1.0000E-003
# 2                                865.63  1.0000E-003
# 3                                867.38  7.4608E-004
# 4                                869.13  0.0000E+000

# %% [markdown]
# looks like these files are the same exact fromat as the .TRM files, so we can reuse the parser!

# %%
df_abs = parse_abs_files()

# %%
df_abs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 0
# Columns: 516 entries, 862.13 to process_method
# dtypes: datetime64[ns](1), float64(510), object(5)
# memory usage: 387.8+ KB

# %%
df_abs.describe()
# Out:
# 0           862.13        863.88        865.63     867.38     869.13   \
# count  9.600000e+01  9.600000e+01  9.600000e+01  96.000000  96.000000
# mean   1.000000e-03  1.000000e-03  1.000000e-03   0.003866   0.015204
# std    2.179787e-19  2.179787e-19  2.179787e-19   0.078384   0.293815
# min    1.000000e-03  1.000000e-03  1.000000e-03  -0.151080  -0.647130
# 25%    1.000000e-03  1.000000e-03  1.000000e-03   0.000746   0.000000
# 50%    1.000000e-03  1.000000e-03  1.000000e-03   0.000746   0.000000
# 75%    1.000000e-03  1.000000e-03  1.000000e-03   0.000746   0.000000
# max    1.000000e-03  1.000000e-03  1.000000e-03   0.489260   1.273900
#
# 0        870.88     872.63     874.38     876.13     877.88   ...    1737.13  \
# count  96.000000  96.000000  96.000000  96.000000  96.000000  ...  96.000000
# mean    0.105489   0.226209   0.210638   0.213721   0.226898  ...   0.270371
# std     0.200905   0.069105   0.067286   0.067480   0.069031  ...   0.081136
# ...

# %%
df_abs.head()
# Out:
# 0  862.13  863.88  865.63    867.38   869.13   870.88   872.63   874.38  \
# 0   0.001   0.001   0.001  0.000746  0.00000  0.09804  0.23904  0.22139
# 0   0.001   0.001   0.001  0.088220  0.37437  0.32127  0.17101  0.15918
# 0   0.001   0.001   0.001  0.000746  0.00000  0.10764  0.25807  0.24305
# 0   0.001   0.001   0.001  0.000746  0.00000  0.10400  0.25080  0.23672
# 0   0.001   0.001   0.001  0.097632  0.46666  0.55056  0.44727  0.43291
#
# 0   876.13   877.88  ...  1747.63  1749.38  1751.13  1752.88  \
# 0  0.22554  0.24124  ...  0.28247  0.28147  0.28053  0.27958
# 0  0.16184  0.17219  ...  0.20912  0.20875  0.20827  0.20764
# 0  0.24577  0.25723  ...  0.29995  0.29980  0.29959  0.29915
# 0  0.23925  0.25092  ...  0.28670  0.28666  0.28670  0.28635
# 0  0.43860  0.45731  ...  0.50545  0.50380  0.50198  0.50045
#
# 0                                         extra_info  \
# 0   File: Users\stell\Desktop\StellarDat\South 18...
# 0   File: Users\stell\Desktop\StellarDat\South 16...
# ...
